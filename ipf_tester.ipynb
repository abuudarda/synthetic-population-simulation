# %%
import pandas as pd
import numpy as np
import random
import itertools

np.random.seed(37)
random.seed(37)

height = [
    np.random.normal(5.5, 1.0, 100),
    np.random.normal(5.3, 1.0, 200),
    np.random.normal(5.9, 1.0, 300),
    np.random.normal(5.7, 1.0, 200),
    np.random.normal(5.3, 1.0, 400),
    np.random.normal(5.2, 1.0, 500),
    np.random.normal(5.8, 1.0, 300),
    np.random.normal(5.5, 1.0, 200)
]

demographic = [
    ['white', 'minor', 'male'],
    ['white', 'minor', 'female'],
    ['white', 'adult', 'male'],
    ['white', 'adult', 'female'],
    ['other', 'minor', 'male'],
    ['other', 'minor', 'female'],
    ['other', 'adult', 'male'],
    ['other', 'adult', 'female']
]

data = [[{'race': d[0], 'age': d[1], 'gender': d[2], 'height': h} for h in s]
        for d, s in zip(demographic, height)]
for i in data: 
    print(i)
data = list(itertools.chain(*data))

df = pd.DataFrame(data)
df.to_csv("garbage//testDump.csv",header=True)
df.head()
# Out:
# [{'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 5.445536387662503}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 6.174308066353492}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 5.8466470259584336}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 4.199653829045987}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 7.0185118788747625}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 6.489823705535016}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 5.777680897136328}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 5.051410645704926}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 6.461966243523971}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 4.6724213607936775}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 6.034657065334038}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 6.728386188788861}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 6.019592333422819}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 5.436645180976146}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 5.465206642661041}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 5.545565547096166}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 6.948025131672427}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 7.393505533070051}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 5.903032304911052}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 5.692426087246758}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 5.196306950233681}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 4.6402286068507035}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 5.232653128019224}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 3.4308520713362753}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 4.789868763955792}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 6.121550297901098}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 6.72148625848438}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 3.7835467592693384}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 5.104149521515229}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 6.773775774404107}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 5.490331877395254}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 5.36195887229657}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 5.9441642252501765}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 3.4529325606621746}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 5.273937355983752}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 7.127953558059943}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 4.706921963131875}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 7.25902821212546}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 5.560475689469003}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 5.857610656140727}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 5.566567327614452}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 5.86252740877137}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 5.198887817117647}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 3.4472173092330998}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 7.177810821626591}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 5.085536588736883}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 6.460494181726631}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'height': 5.842947792277082}, {'race': 'white', 'age': 'minor', 'gender': 'male', 'heigh ...
# [{'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 6.15214120038979}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 6.398585619118175}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 5.010760438719462}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 7.511154269254305}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 4.732390426907621}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 5.977452325317174}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 4.787330055996961}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 4.654967496540737}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 5.466593044315499}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 5.862224297579924}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 6.964327247808357}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 5.511327371209111}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 6.627620194977098}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 5.2762333422698875}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 5.250326825833386}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 3.9545878771797733}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 4.533128543399172}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 5.5995983154900735}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 7.0980437285938045}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 4.395673651555499}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 6.503432202951128}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 4.37295082907237}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 6.620709866290124}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 5.884021104738258}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 5.202673448509547}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 7.083491211381279}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 4.157882633303125}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 4.4992820082965945}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 6.690160923723425}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 5.935772495146889}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 5.315476015459341}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 5.679861218378694}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 6.252218058986131}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 6.169313886230198}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 5.43613244805022}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 4.891844987374122}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 3.828808922519509}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 7.015469751778374}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 6.441611761959396}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 3.879876881803041}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 4.03318762957355}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 3.777167276954909}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 4.243658097524618}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 5.081419968816586}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 4.840545219462434}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 4.844291142511851}, {'race': 'white', 'age': 'minor', 'gender': 'female', 'height': 5.705751864270019}, {'race': 'white', 'age': 'minor', 'gender': 'femal ...
# [{'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 6.5498749280378314}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 4.628700445228557}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 3.66910630738352}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 5.211447426922986}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 4.729444789710088}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 5.082598344659066}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 5.249189404626388}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 5.006533569248752}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 5.839087705877505}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 6.749287481587573}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 5.682792769820485}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 6.096110119595029}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 6.778126207397393}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 3.573906369570692}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 5.717138814512167}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 3.9744702773493943}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 4.63168375512138}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 5.920333655179825}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 5.622360158436157}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 5.609820978412847}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 8.164145212996825}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 5.057335504580984}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 6.592757020808717}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 7.272546772230721}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 5.637250571232773}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 6.144224647799199}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 6.025397255382547}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 6.502812965927837}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 8.506971696977274}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 6.506023555871761}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 5.964983519081692}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 2.889051901346613}, {'race': 'white', 'age': 'adult', 'gender': 'male', 'height': 5
, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 7.202063497045784}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 4.8246899090923785}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 5.26108942504501}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 5.457234926460133}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 5.045754979080899}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 6.15410832786458}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 4.1771728259321765}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 5.425784829293731}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 4.435642461191165}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 7.5735197578619085}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 6.420356146226747}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 5.463090404090166}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 6.6033188046033136}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 6.701742397664919}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 5.0490906830451845}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 6.642918339234666}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 4.464409578504957}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 4.92754012116214}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 4.361653972143863}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 5.111240641824107}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 5.701138627938195}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 5.760332561784256}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 4.983002414805311}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 6.320207074442473}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 5.176046710346113}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 6.226118001674654}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 6.01798588848416}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 4.920540449187868}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 4.6227178970412055}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 5.5558943767721525}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 5.2440123399680925}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 4.531502006453728}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 5.89876895845153}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 7.463675759670698}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'height': 6.808468922270769}, {'race': 'other', 'age': 'adult', 'gender': 'male', 'heigh ...
# [{'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 5.554521685898704}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 4.381048171659022}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 5.28171172610417}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 3.5523888490854194}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 6.066011132132642}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 6.437544116600578}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 2.8654156508088695}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 5.741298131236433}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 6.021332780362532}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 7.597915465724451}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 7.306351179696351}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 6.934864849330694}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 5.21612897001772}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 4.943219570600268}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 5.944171425130092}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 6.343145810865064}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 5.836629876027463}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 5.353080715850657}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 5.2233827501057934}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 5.393664974558666}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 4.8920217927812555}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 5.465241968211215}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 5.176253403586325}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 4.067760900415311}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 5.896862698917828}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 6.200851642517879}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 5.049041261876198}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 3.0957897005502075}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 7.140897108222472}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 6.022285201822354}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 5.0038073601752115}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 5.211809405367872}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 5.5695112713452755}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 5.754079618191141}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 6.243499685259151}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 5.817802088930451}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 4.492793802278404}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 7.363154524825407}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 6.593906309223213}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 5.286220668691802}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 5.167871027748239}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 5.276968524044398}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 6.204181046804826}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 4.703779974614803}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 6.547356232286553}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 6.602155305326054}, {'race': 'other', 'age': 'adult', 'gender': 'female', 'height': 6.71966888885305}, {'race': 'other', 'age': 'adult', 'gender': 'fe ...
#     race    age gender    height
# 0  white  minor   male  5.445536
# 1  white  minor   male  6.174308
# 2  white  minor   male  5.846647
# 3  white  minor   male  4.199654
# 4  white  minor   male  7.018512

# %%
def get_target_marginals(d):
    factors = list(d.keys())
    targets = [sorted([(k2, v2) for k2, v2 in v.items()]) for k, v in d.items()]
    targets = np.array([[v for _, v in item] for item in targets])
    print("inside func",type(targets))


    return factors, targets

def get_table(df, targets):
    factors, target_marginals = get_target_marginals(targets)

    cross_tab = pd.crosstab(df[factors[0]], [df[c] for c in factors[1:]])
    shape = tuple([df[c].unique().shape[0] for c in factors])
    table = cross_tab.values.reshape(shape)

    return factors, target_marginals, table

f, u, X = get_table(df, {
    'race': {'white': 5800, 'other': 4200},
    'age': {'minor': 2800, 'adult': 7200},
    'gender': {'male': 4900, 'female': 5100}
})
# Out:
# inside func <class 'numpy.ndarray'>

# %%
X.shape
# Out:
# (2, 2, 2)

# %%
type(X)
# Out:
# numpy.ndarray

# %%
X
# Out:
# array([[[200, 300],
#         [500, 400]],
#
#        [[200, 300],
#         [200, 100]]], dtype=int64)

# %%
for i in u:
    print(type(i))
    for j in i :
        print(type(j))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.int32'>
# <class 'numpy.int32'>
# <class 'numpy.ndarray'>
# <class 'numpy.int32'>
# <class 'numpy.int32'>
# <class 'numpy.ndarray'>
# <class 'numpy.int32'>
# <class 'numpy.int32'>

# %%
u
# Out:
# array([[4200, 5800],
#        [7200, 2800],
#        [5100, 4900]])

# %%
def get_coordinates(M):
    return list(itertools.product(*[list(range(n)) for n in M.shape]))

def get_marginals(M, i):
    coordinates = get_coordinates(M)

    key = lambda tup: tup[0]
    counts = [(c[i], M[c]) for c in coordinates]
    counts = sorted(counts, key=key)
    counts = itertools.groupby(counts, key=key)
    counts = {k: sum([v[1] for v in g]) for k, g in counts}

    return counts

def get_all_marginals(M):
    return np.array([[v for _, v in get_marginals(M, i).items()]
                     for i in range(len(M.shape))])

def get_counts(M, i):
    coordinates = get_coordinates(M)

    key = lambda tup: tup[0]
    counts = [(c[i], M[c], c) for c in coordinates]
    counts = sorted(counts, key=key)
    counts = itertools.groupby(counts, key=key)
    counts = {k: [(tup[1], tup[2]) for tup in g] for k, g in counts}

    return counts

def update_values(M, i, u):
    marg = get_marginals(M, i)
    vals = get_counts(M, i)

    d = [[(c, n * u[k] / marg[k]) for n, c in v] for k, v in vals.items()]
    d = itertools.chain(*d)
    d = list(d)

    return d

def ipf_update(M, u):
    for i in range(len(M.shape)):
        values = update_values(M, i, u[i])
        for idx, v in values:
            M[idx] = v

    o = get_all_marginals(M)
    d = get_deltas(o, u)

    return M, d

def get_deltas(o, t):
    return np.array([np.linalg.norm(o[r] - t[r], 2) for r in range(o.shape[0])])

def get_weights(X, max_iters=50, zero_threshold=0.0001, convergence_threshold=3, debug=True):
    M = X.copy()

    d_prev = np.zeros(len(M.shape))
    count_zero = 0

    for _ in range(max_iters):
        M, d_next = ipf_update(M, u)
        d = np.linalg.norm(d_prev - d_next, 2)

        if d < zero_threshold:
            count_zero += 1

        if debug:
            print(','.join([f'{v:.5f}' for v in d_next]), d)
        d_prev = d_next

        if count_zero >= convergence_threshold:
            break

    w = M / M.sum()
    return w

# %%
w = get_weights(X)
# Out:
# 758.02375,123.06909,3.16228 767.9557278906121
# 75.74299,7.28011,3.60555 692.0363565714724
# 6.70820,2.23607,2.23607 69.23235546955618
# 2.23607,2.23607,2.23607 4.47213595499958
# 2.23607,2.23607,2.23607 0.0
# 2.23607,2.23607,2.23607 0.0
# 2.23607,2.23607,2.23607 0.0

# %%
w
# Out:
# array([[[0.113334  , 0.13604081],
#         [0.10423127, 0.0663199 ]],
#
#        [[0.21406422, 0.256677  ],
#         [0.0783235 , 0.0310093 ]]])

# %%
import functools

def get_sampling_weights(df, f, w):
    get_filters = lambda df, fields, values: [df[f] == v for f, v in zip(fields, values)]
    get_total = lambda df, fields, values: df[functools.reduce(lambda a, b: a & b, get_filters(df, fields, values))].shape[0]

    return {k: v / get_total(df, f, k) for k, v in zip(list(itertools.product(*[sorted(df[c].unique()) for c in f])), np.ravel(w))}

def get_samples(df, f, w, n=10_000):
    weights = get_sampling_weights(df, f, w)
    s = df.apply(lambda r: weights[tuple([r[c] for c in f])], axis=1)
    return df.sample(n=n, replace=True, weights=s)

sample_df = get_samples(df, f, w)
sample_df
# Out:
#        race    age  gender    height
# 1461  other  minor  female  5.337720
# 2034  other  adult  female  6.243500
# 1715  other  adult    male  5.261089
# 310   white  adult    male  5.682793
# 1884  other  adult    male  5.192252
# ...     ...    ...     ...       ...
# 2140  other  adult  female  6.026459
# 732   white  adult  female  5.155105
# 34    white  minor    male  5.273937
# 117   white  minor  female  5.599598
# 649   white  adult  female  6.546797
#
# [10000 rows x 4 columns]

# %%
ct = pd.crosstab(sample_df.race, [sample_df.age, sample_df.gender])
ct
# Out:
# age     adult        minor
# gender female  male female male
# race
# other    1165  1344   1041  628
# white    2225  2492    791  314

# %%
sample_df.race.value_counts().sort_index() / sample_df.shape[0]
# Out:
# other    0.4178
# white    0.5822
# Name: race, dtype: float64

# %%
sample_df.age.value_counts().sort_index() / sample_df.shape[0]
# Out:
# adult    0.7226
# minor    0.2774
# Name: age, dtype: float64

# %%
sample_df.gender.value_counts().sort_index() / sample_df.shape[0]
